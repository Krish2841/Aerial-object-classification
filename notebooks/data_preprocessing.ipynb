# %%
# !pip install tensorflow
# Out:
# Collecting tensorflow
#   Using cached tensorflow-2.21.0-cp310-cp310-win_amd64.whl (350.6 MB)
# Collecting flatbuffers>=25.9.23
#   Using cached flatbuffers-25.12.19-py2.py3-none-any.whl (26 kB)
# Collecting opt_einsum>=2.3.2
#   Using cached opt_einsum-3.4.0-py3-none-any.whl (71 kB)
# Collecting h5py<3.15.0,>=3.11.0
#   Using cached h5py-3.14.0-cp310-cp310-win_amd64.whl (2.9 MB)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\krish\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (2.2.6)
# Collecting ml_dtypes<1.0.0,>=0.5.1
#   Using cached ml_dtypes-0.5.4-cp310-cp310-win_amd64.whl (210 kB)
# Collecting libclang>=13.0.0
#   Using cached libclang-18.1.1-py2.py3-none-win_amd64.whl (26.4 MB)
# Collecting protobuf<8.0.0,>=6.31.1
#   Using cached protobuf-7.34.1-cp310-abi3-win_amd64.whl (437 kB)
# Collecting termcolor>=1.1.0
#   Using cached termcolor-3.3.0-py3-none-any.whl (7.7 kB)
# Collecting absl-py>=1.0.0
#   Using cached absl_py-2.4.0-py3-none-any.whl (135 kB)
# Requirement already satisfied: packaging in c:\users\krish\appdata\roaming\python\python310\site-packages (from tensorflow) (26.1)
# Requirement already satisfied: typing_extensions>=3.6.6 in c:\users\krish\appdata\roaming\python\python310\site-packages (from tensorflow) (4.15.0)
# Collecting grpcio<2.0,>=1.24.3
#   Using cached grpcio-1.80.0-cp310-cp310-win_amd64.whl (4.9 MB)
# Collecting gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1
#   Using cached gast-0.7.0-py3-none-any.whl (22 kB)
# Requirement already satisfied: setuptools in c:\users\krish\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (65.5.0)
# Collecting astunparse>=1.6.0
#   Using cached astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Requirement already satisfied: six>=1.12.0 in c:\users\krish\appdata\roaming\python\python310\site-packages (from tensorflow) (1.17.0)
# Collecting wrapt>=1.11.0
#   Using cached wrapt-2.1.2-cp310-cp310-win_amd64.whl (60 kB)
# Collecting keras>=3.12.0
#   Using cached keras-3.12.1-py3-none-any.whl (1.5 MB)
# Collecting google_pasta>=0.1.1
#   Using cached google_pasta-0.2.0-py3-none-any.whl (57 kB)
# Collecting requests<3,>=2.21.0
#   Using cached requests-2.33.1-py3-none-any.whl (64 kB)
# Collecting wheel<1.0,>=0.23.0
#   Using cached wheel-0.46.3-py3-none-any.whl (30 kB)
# Collecting rich
#   Using cached rich-15.0.0-py3-none-any.whl (310 kB)
# Collecting optree
#   Using cached optree-0.19.0-cp310-cp310-win_amd64.whl (321 kB)
# Collecting namex
#   Using cached namex-0.1.0-py3-none-any.whl (5.9 kB)
# Collecting idna<4,>=2.5
#   Using cached idna-3.11-py3-none-any.whl (71 kB)
# Collecting certifi>=2023.5.7
#   Using cached certifi-2026.2.25-py3-none-any.whl (153 kB)
# Collecting urllib3<3,>=1.26
#   Using cached urllib3-2.6.3-py3-none-any.whl (131 kB)
# Collecting charset_normalizer<4,>=2
#   Using cached charset_normalizer-3.4.7-cp310-cp310-win_amd64.whl (159 kB)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\krish\appdata\roaming\python\python310\site-packages (from rich->keras>=3.12.0->tensorflow) (2.20.0)
# Collecting markdown-it-py>=2.2.0
#   Using cached markdown_it_py-4.0.0-py3-none-any.whl (87 kB)
# Collecting mdurl~=0.1
#   Using cached mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Installing collected packages: namex, libclang, flatbuffers, wrapt, wheel, urllib3, termcolor, protobuf, optree, opt_einsum, ml_dtypes, mdurl, idna, h5py, grpcio, google_pasta, gast, charset_normalizer, certifi, absl-py, requests, markdown-it-py, astunparse, rich, keras, tensorflow
# Successfully installed absl-py-2.4.0 astunparse-1.6.3 certifi-2026.2.25 charset_normalizer-3.4.7 flatbuffers-25.12.19 gast-0.7.0 google_pasta-0.2.0 grpcio-1.80.0 h5py-3.14.0 idna-3.11 keras-3.12.1 libclang-18.1.1 markdown-it-py-4.0.0 mdurl-0.1.2 ml_dtypes-0.5.4 namex-0.1.0 opt_einsum-3.4.0 optree-0.19.0 protobuf-7.34.1 requests-2.33.1 rich-15.0.0 tensorflow-2.21.0 termcolor-3.3.0 urllib3-2.6.3 wheel-0.46.3 wrapt-2.1.2
# [notice] A new release of pip available: 22.3.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
train_datagen = ImageDataGenerator(
    rescale = 1./255,
    rotation_range = 20,
    width_shift_range = 0.1,
    height_shift_range = 0.1,
    zoom_range = 0.2,
    horizontal_flip = True
)

# %%
valid_datagen = ImageDataGenerator(rescale = 1./255)

# %%
test_datagen = ImageDataGenerator(rescale = 1./255)

# %%
train_data = train_datagen.flow_from_directory(
    "K:/Aerial_project/data/train",
    target_size = (224, 224),
    batch_size = 32,
    class_mode = "binary"
)

valid_data = valid_datagen.flow_from_directory(
    "K:/Aerial_project/data/valid",
    target_size = (224, 224),
    batch_size = 32,
    class_mode = "binary"
)

test_data = test_datagen.flow_from_directory(
    "K:/Aerial_project/data/test",
    target_size = (224, 224),
    batch_size = 32,
    class_mode = "binary",
    shuffle = False
)
# Out:
# Found 2662 images belonging to 2 classes.
# Found 442 images belonging to 2 classes.
# Found 215 images belonging to 2 classes.

# %%
print(train_data.class_indices)
# Out:
# {'bird': 0, 'drone': 1}
